# %%
# %matplotlib inline

# %%
# Import dependencies 
import matplotlib.pyplot as plt

# %%
# Set the x axis to a list of string for each month 
x_axis = ["Jan", "Feb","Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]
# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month 
y_axis =[10.02,23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot 
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
#Create the plot. 
plt.plot(x_axis, y_axis)
plt.show()

# %%
#Create the plot and add a label for the legend 
plt.plot(x_axis, y_axis, label = "Boston")

#Create labels for the x and y axes. 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y limit between 0 and 45. 
plt.ylim(0,45)

# Create a title 
plt.title("PyBer Fare by Month")

#Add the legend. 
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-0325ea0bc8fd> in <module>
#       3
#       4 #Create labels for the x and y axes.
# ----> 5 plt.xlabel("Date")
#       6 plt.ylabel("Fare($)")
#       7
#
# TypeError: 'str' object is not callable

# %%
# Create the plot. 
plt.plot(x_axis, y_axis, marker = "*", color = "blue", linewidth = 2, label = "Boston")

# Create labels for the x and y axes. 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Set the y limit between 0 and 45.
plt.ylim(0,45)

#Create a title 
plt.title("PyBer Fare by Month")

# Add a grid 
plt.grid()

# Add the legend. 
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-afcdad5026a5> in <module>
#       3
#       4 # Create labels for the x and y axes.
# ----> 5 plt.xlabel("Date")
#       6 plt.ylabel("Fare($)")
#       7
#
# TypeError: 'str' object is not callable

# %%
# Skill Drill in 5.1.4
ax = plt.axes()
ax.plot(x_axis, y_axis, color = "green", marker = "*", linewidth = 2, label = "Boston")
ax.legend()
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.set_title("PyBer Fare by Month")
ax.set_ylim(0,45)
ax.grid()

# %%
# Create the bar plot 
plt.bar(x_axis, y_axis, color = "green", label = "Boston")

#Create labels for the x and y axes. 
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title 
plt.title("PyBer Fare by Month")

#Add the legend 
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-db67846d364d> in <module>
#       3
#       4 #Create labels for the x and y axes.
# ----> 5 plt.xlabel("Date")
#       6 plt.ylabel("Fare($)")
#       7
#
# TypeError: 'str' object is not callable

# %%
# Create the plot 
plt.barh(x_axis, y_axis, color = "magenta", )
plt.gca().invert_yaxis()

# %%
# Skill Drill 5.1.5 
plt.barh(x_axis, y_axis, color = "magenta", label = "Boston")
plt.xlabel = ("Fare($)")
plt.ylabel = ("Date")
plt.legend()
plt.title ("PyBer Fare by Month")
plt.gca().invert_yaxis()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-71ceff7b3228> in <module>
#       4 plt.ylabel = ("Date")
#       5 plt.legend()
# ----> 6 plt.title ("PyBer Fare by Month")
#       7 plt.gca().invert_yaxis()
#
# TypeError: 'str' object is not callable

# %%
# Create the plot with ax.plot()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plot()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill Drill 5.1.6
ax = plt.axes()
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
ax.legend()
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
ax.set_title("PyBer Fare by Month")
ax.invert_yaxis()

# %%
plt.plot(x_axis,y_axis, "o")

# %%
# Skill Drill 5.1.7
plt.scatter(x_axis, y_axis, c = "red", label = "Chicago") 
plt.legend()
plt.xlabel("Date")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-c30c6d6aa8a1> in <module>
#       2 plt.scatter(x_axis, y_axis, c = "red", label = "Chicago")
#       3 plt.legend()
# ----> 4 plt.xlabel("Date")
#
# TypeError: 'str' object is not callable

# %%
plt.scatter(x_axis,y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis: 
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis,y_axis, s = y_axis_larger)

# %%
plt.scatter(x_axis,y_axis, s = [i *3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis, color = "skyblue")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Out:
# Text(0, 0.5, 'Fare($)')
